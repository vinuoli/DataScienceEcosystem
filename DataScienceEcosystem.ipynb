# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# En este cuaderno, se resumen las herramientas y ecosistemas de ciencia de datos.

# %% [markdown]
# **Objetivos:**
# - Listar lenguajes populares para ciencia de datos
# - Listar bibliotecas comúnmente utilizadas para ciencia de datos
# - Ejemplos de evaluación de expresiones aritméticas en Python
#     - Una expresión aritmética simple para multiplicar y luego sumar enteros
#     - Convertir 200 minutos a horas

# %% [markdown]
# Algunos de los lenguajes populares que utilizan los científicos de datos son:
# 1. Pyhton
# 2. R
# 3. Java

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
# 1. pandas (Python)
# 2. NumPy (Python)
# 3. scikit-learn (Python)
# 4. Matplotlib (Python)
# 5. Seaborn (Python)
# 6. TensorFlow (Python)

# %% [markdown]
# |Herramientas de Ciencia de Dato |
# | ------ |
# | Jupyter Notebook |
# |Apache Spark |
# | RStudio |

# %% [markdown]
# ### A continuación se presentan algunos ejemplos de evaluación de expresiones aritméticas en Python

# %%
# Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
(3*4)+5
# Out:
# 17

# %%
# Esto convertirá 200 minutos a horas dividiendo por 60
minutos = 200
horas = minutos / 60 
print(f"{minutos} minutos son {horas} horas")
# Out:
# 200 minutos son 3.3333333333333335 horas

# %% [markdown]
# ## Autor
# Victoria Núñez Oliveira
